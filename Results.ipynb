# %% [markdown]
# # Neural Machine Translation & CoVe
#
# ## training NMT model
# We trained our NMT model on a large and a small dataset seperately. We trained the result for 2 days.
#
# ### result on small dataset
# training loss:
# <img src="./images/small_loss.png" alt="Alt text that describes the graphic" title="training loss" />
# BLEU score:
# <img src="./images/small_test.png" alt="Alt text that describes the graphic" title="training loss" />
# ### result on large dataset
# training loss:
# <img src="./images/large_loss.png" alt="Alt text that describes the graphic" title="training loss" />
# BLEU score:
# <img src="./images/large_test.png" alt="Alt text that describes the graphic" title="training loss" />

# %% [markdown]
# ## NMT training log

# %%
! cat ./text/nmt_train_log.txt
# Out:
# # Job id 0
# 2018-12-12 17:34:10.770381: I tensorflow/core/platform/cpu_feature_guard.cc:140] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2018-12-12 17:34:10.863891: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:898] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2018-12-12 17:34:10.864332: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1356] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# totalMemory: 11.17GiB freeMemory: 11.09GiB
# 2018-12-12 17:34:10.864358: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1435] Adding visible gpu devices: 0
# 2018-12-12 17:34:11.149778: I tensorflow/core/common_runtime/gpu/gpu_device.cc:923] Device interconnect StreamExecutor with strength 1 edge matrix:
# ...

# %% [markdown]
# ## NMT translation sample
# from English to German

# %%
! cat ./text/nmt_translation_sample.txt
# Out:
# <unk> <unk> Sicherheit für <unk>
# Sie sind nicht einmal 100 Meter <unk> auf dem neuen B 33 <unk> in <unk> in <unk> wurde in <unk> Jahren - im Hinblick auf die bestehenden <unk>
# Zwei Formen der <unk> so enge <unk> oder nur eine <unk> <unk>
# <unk> <unk> <unk> hat eine klare Antwort auf diese Entschließung <unk>
# Die <unk> wurde seit dem <unk> der Stadt <unk> weil dies eine Schule <unk> erklärt <unk>
# Die <unk> <unk> schützen ebenso weit wie auch die von den <unk> und die Bewohner von <unk>
# Die <unk> die offiziell offiziell durchgeführt <unk> ist von Bedeutung für die <unk> <unk>
# Wir haben die beiden <unk> die <unk> des <unk> ein <unk> Verfahren und eine <unk> nicht vergessen und nicht die <unk> von den <unk> <unk>
# Die Zeit hoher <unk> und <unk> eines zusätzlichen <unk> wurden für eine <unk> <unk> um <unk> zu <unk>
# Das wurde auch vom Peter <unk> von dem <unk> <unk> <unk>
# ...

# %% [markdown]
# ## generating CoVe
# the CoVE vector of the input English corpus 'newstest2014'

# %%
! cat ./text/cove_output.txt
# Out:
# # Job id 0
# # Devices visible to TensorFlow: [_DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 268435456), _DeviceAttributes(/job:localhost/replica:0/task:0/device:GPU:0, GPU, 11270098125)]
# # Loading hparams from /home/ecbm4040/cove_first_try/nmt_attention_model/hparams
# # Vocab file /home/ecbm4040/nmt/nmt_data/vocab.bpe.32000.en exists
# # Vocab file /home/ecbm4040/nmt/nmt_data/vocab.bpe.32000.de exists
#   saving hparams to /home/ecbm4040/cove_first_try/nmt_attention_model/hparams
#   saving hparams to /home/ecbm4040/nmt/nmt_attention_model/best_bleu/hparams
#   attention=luong
#   attention_architecture=standard
#   avg_ckpts=False
#   batch_size=128
#   beam_width=0
#   best_bleu=4.114320473174836
#   best_bleu_dir=/home/ecbm4040/nmt/nmt_attention_model/best_bleu
#   check_special_token=True
#   colocate_gradients_with_ops=True
#   decay_scheme=
#   dev_prefix=/home/ecbm4040/nmt/nmt_data/newstest2014
#   dropout=0.2
#   embed_prefix=None
# ...

# %% [markdown]
# # Classification (Compare CoVe and GloVe)
#
# training loss:
# <img src="./images/bcn_loss.png" alt="Alt text that describes the graphic" title="training loss" />
#
# accuracy:
# <img src="./images/bcn_accuracy.png" alt="Alt text that describes the graphic" title="training loss" />
#
# F1-score:
# <img src="./images/bcn_f1.png" alt="Alt text that describes the graphic" title="training loss" />

# %% [markdown]
# # Question Answering (Compare GloVe and CoVe)

# %% [markdown]
# training loss: Development set loss on our GloVe (light blue) and GloVe+CoVe model (dark blue) at SQuAd dataset
# <img src="./images/dcn_loss.png" alt="Alt text that describes the graphic" title="training loss" />
#
# F1-score of our best model:
# <img src="./images/dcn_f1.png" alt="Alt text that describes the graphic" title="training loss" />
